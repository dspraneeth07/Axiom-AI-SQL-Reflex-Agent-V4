# %% [markdown]
# <a href="https://colab.research.google.com/github/dspraneeth07/Axiom-AI-SQL-Reflex-Agent-V4/blob/main/notebooks/00_env_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q duckdb pandas numpy pyarrow tqdm
# !pip install -q sentence-transformers faiss-cpu
# !pip install -q gdown

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import os

AXIOM_ROOT = "/content/drive/MyDrive/Axiom"

# Create folder if it doesn't exist
os.makedirs(AXIOM_ROOT, exist_ok=True)

# Move into Axiom directory
os.chdir(AXIOM_ROOT)

print("📁 Current working directory:", os.getcwd())
# Out:
# 📁 Current working directory: /content/drive/MyDrive/Axiom

# %%
import duckdb
import pandas as pd

db = duckdb.connect("axiom_v4.duckdb")

db.execute("SELECT 1").fetchall()
# Out:
# [(1,)]

# %%
import os
import zipfile
import gdown

# Ensure directory exists
SPIDER_DIR = "data/spider"
os.makedirs(SPIDER_DIR, exist_ok=True)

# Google Drive file ID
file_id = "1403EGqzIDoHMdQF4c9Bkyl7dZLZ5Wt6J"
zip_path = os.path.join(SPIDER_DIR, "spider.zip")

# Download
gdown.download(
    f"https://drive.google.com/uc?id={file_id}",
    zip_path,
    quiet=False
)

# Extract
with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(SPIDER_DIR)

print("✅ Spider dataset downloaded and extracted")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1403EGqzIDoHMdQF4c9Bkyl7dZLZ5Wt6J
# From (redirected): https://drive.google.com/uc?id=1403EGqzIDoHMdQF4c9Bkyl7dZLZ5Wt6J&confirm=t&uuid=3162dd82-9aaa-4575-b775-60064154eb54
# To: /content/drive/MyDrive/Axiom/data/spider/spider.zip
# 100%|██████████| 206M/206M [00:05<00:00, 38.8MB/s]
# ✅ Spider dataset downloaded and extracted

# %%
# !git clone https://github.com/AlibabaResearch/DAMO-ConvAI.git data/bird_raw
import os

os.listdir("data/bird_raw")
# Out:
# fatal: destination path 'data/bird_raw' already exists and is not an empty directory.
# ['.git',
#  '.DS_Store',
#  '.github',
#  '.gitignore',
#  'Awesome-Self-Evolution-of-LLM',
#  'EPO',
#  'FlowBench',
#  'IOPO',
#  'LICENSE',
#  'Loong',
#  'MaskedThought',
#  'OmniCharacter',
#  'OpenOmni',
#  'PRO',
#  'README.md',
#  'RPM-Generalization',
#  'SDPO',
#  'WideDeep',
#  'acl23doc2dial',
#  'api-bank',
#  'attention-buckets',
#  'bird',
#  'cats',
#  'cgodial',
#  'dater',
#  'deep-thinking',
#  'dial-start',
#  'dial2vec',
#  'dialogue-cse',
#  'diana',
#  'doc2bot',
#  'dstc11-simmc',
#  'graphix',
#  'metaretriever',
#  'mmevol',
#  'oltqa',
#  'pace',
#  'pcll',
#  'proton',
#  'r2sql',
#  'rlp',
#  's2sql',
#  'sdsql',
#  'space-1',
#  'space-2',
#  'space-3',
#  'spectra',
#  'spokenwoz',
#  'ssll',
#  'star',
#  'sunsql',
#  'tkk',
#  'unid2t']

# %%
spider_db_path = "data/spider/spider_data/database"

# list first few databases
print(os.listdir(spider_db_path)[:5])
# Out:
# ['browser_web', 'musical', 'farm', 'voter_1', 'game_injury']

# %%
print(os.listdir("data/bird_raw")[:5])
# Out:
# ['.git', '.DS_Store', '.github', '.gitignore', 'Awesome-Self-Evolution-of-LLM']
